# %%
from google.colab import files
import pandas as pd
import os
import shutil
import numpy as np
from PIL import Image
from collections import Counter
from tqdm.notebook import tqdm as tq
import cv2
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pathlib
import cv2
import albumentations as A
import numpy as np

# %%
from google.colab import files
files.upload()

# %%
# Download kaggle dataset and unzip the file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download ashishmotwani/tomato
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ashishmotwani/tomato
# License(s): copyright-authors
# Downloading tomato.zip to /content
#  96% 1.31G/1.37G [00:12<00:01, 41.7MB/s]
# 100% 1.37G/1.37G [00:12<00:00, 120MB/s]

# %%
# !unzip tomato.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: valid/Late_blight/9aaf4a7d-12ac-457a-a18c-1f7ea13065de___RS_Late.B 5179.JPG
#   inflating: valid/Late_blight/9afc2537-1b13-4c25-b5ed-5b8de511b0ab___GHLB2 Leaf 9033.JPG
#   inflating: valid/Late_blight/9bb49d22-976d-40c3-bc9a-bff5cbbd8e28___RS_Late.B 5057.JPG
#   inflating: valid/Late_blight/9c274db5-2f89-4f3c-b9e2-4d5ebc54ddad___GHLB2 Leaf 9096.JPG
#   inflating: valid/Late_blight/9c726f4e-045b-4080-b53d-d7e66d45bcb1___RS_Late.B 4876.JPG
#   inflating: valid/Late_blight/9e5dd34f-124c-4a64-ba9f-77c8d05faa9c___GHLB2 Leaf 8749.JPG
#   inflating: valid/Late_blight/9e633823-3dde-450c-8172-733021e4dff0___RS_Late.B 6414.JPG
#   inflating: valid/Late_blight/9ecb8001-2f48-4487-b287-535dbcfb5c2f___RS_Late.B 6206.JPG
#   inflating: valid/Late_blight/9f7dcd60-e691-4c1e-830e-7495f7cc123d___RS_Late.B 6166.JPG
#   inflating: valid/Late_blight/Bacterial_spots2276_jpg.rf.5becd3793ec2a532bf8f111d60911c63.jpg
#   inflating: valid/Late_blight/IMG_1526_jpg.rf.5e25005985e2b12a6f52bfa7120f3eee.jpg
#   inflating: valid/Late_blight/IMG_5360_jpg.rf.7651a731881c678ec115ed74882f3d75.jpg
#   inflating: valid/Late_blight/LB_ (10).jpg
#   inflating: valid/Late_blight/LB_ (101).JPG
#   inflating: valid/Late_blight/LB_ (104).JPG
#   inflating: valid/Late_blight/LB_ (105).JPG
#   inflating: valid/Late_blight/LB_ (106).JPG
#   inflating: valid/Late_blight/LB_ (108).JPG
#   inflating: valid/Late_blight/LB_ (109).JPG
#   inflating: valid/Late_blight/LB_ (110).JPG
#   inflating: valid/Late_blight/LB_ (116).JPG
#   inflating: valid/Late_blight/LB_ (124).JPG
#   inflating: valid/Late_blight/LB_ (13).jpg
#   inflating: valid/Late_blight/LB_ (130).JPG
#   inflating: valid/Late_blight/LB_ (134).JPG
#   inflating: valid/Late_blight/LB_ (139).JPG
#   inflating: valid/Late_blight/LB_ (14).png
#   inflating: valid/Late_blight/LB_ (141).JPG
#   inflating: valid/Late_blight/LB_ (142).JPG
#   inflating: valid/Late_blight/LB_ (143).JPG
#   inflating: valid/Late_blight/LB_ (144).JPG
#   inflating: valid/Late_blight/LB_ (145).JPG
#   inflating: valid/Late_blight/LB_ (146).JPG
#   inflating: valid/Late_blight/LB_ (148).JPG
#   inflating: valid/Late_blight/LB_ (15).jpg
#   inflating: valid/Late_blight/LB_ (157).JPG
#   inflating: valid/Late_blight/LB_ (159).png
#   inflating: valid/Late_blight/LB_ (16).png
#   inflating: valid/Late_blight/LB_ (160).JPG
#   inflating: valid/Late_blight/LB_ (161).JPG
#   inflating: valid/Late_blight/LB_ (163).JPG
#   inflating: valid/Late_blight/LB_ (166).JPG
#   inflating: valid/Late_blight/LB_ (173).JPG
#   inflating: valid/Late_blight/LB_ (175).JPG
#   inflating: valid/Late_blight/LB_ (183).JPG
#   inflating: valid/Late_blight/LB_ (186).JPG
#   inflating: valid/Late_blight/LB_ (188).JPG
#   inflating: valid/Late_blight/LB_ (20).png
#   inflating: valid/Late_blight/LB_ (201).JPG
#   inflating: valid/Late_blight/LB_ (202).JPG
#   inflating: valid/Late_blight/LB_ (205).JPG
#   inflating: valid/Late_blight/LB_ (21).png
#   inflating: valid/Late_blight/LB_ (211).JPG
#   inflating: valid/Late_blight/LB_ (212).JPG
#   inflating: valid/Late_blight/LB_ (214).JPG
#   inflating: valid/Late_blight/LB_ (220).jpg
#   inflating: valid/Late_blight/LB_ (220).png
#   inflating: valid/Late_blight/LB_ (222).jpg
#   inflating: valid/Late_blight/LB_ (223).jpg
#   inflating: valid/Late_blight/LB_ (226).jpg
#   inflating: valid/Late_blight/LB_ (229).png
#   inflating: valid/Late_blight/LB_ (232).jpg
#   inflating: valid/Late_blight/LB_ (233).jpg
#   inflating: valid/Late_blight/LB_ (233).png
#   inflating: valid/Late_blight/LB_ (234).jpg
#   inflating: valid/Late_blight/LB_ (235).png
#   inflating: valid/Late_blight/LB_ (238).jpg
#   inflating: valid/Late_blight/LB_ (239).jpg
#   inflating: valid/Late_blight/LB_ (240).jpg
#   inflating: valid/Late_blight/LB_ (240).png
#   inflating: valid/Late_blight/LB_ (241).png
#   inflating: valid/Late_blight/LB_ (244).png
#   inflating: valid/Late_blight/LB_ (245).jpg
#   inflating: valid/Late_blight/LB_ (246).jpg
#   inflating: valid/Late_blight/LB_ (247).jpg
#   inflating: valid/Late_blight/LB_ (248).jpg
#   inflating: valid/Late_blight/LB_ (248).png
#   inflating: valid/Late_blight/LB_ (249).jpg
#   inflating: valid/Late_blight/LB_ (250).jpg
#   inflating: valid/Late_blight/LB_ (253).png
#   inflating: valid/Late_blight/LB_ (255).png
#   inflating: valid/Late_blight/LB_ (257).jpg
#   inflating: valid/Late_blight/LB_ (262).jpg
#   inflating: valid/Late_blight/LB_ (263).png
#   inflating: valid/Late_blight/LB_ (265).jpg
#   inflating: valid/Late_blight/LB_ (266).jpg
#   inflating: valid/Late_blight/LB_ (267).png
#   inflating: valid/Late_blight/LB_ (270).png
#   inflating: valid/Late_blight/LB_ (272).JPG
#   inflating: valid/Late_blight/LB_ (275).JPG
#   inflating: valid/Late_blight/LB_ (275).png
#   inflating: valid/Late_blight/LB_ (276).png
#   inflating: valid/Late_blight/LB_ (277).png
#   inflating: valid/Late_blight/LB_ (28).JPG
#   inflating: valid/Late_blight/LB_ (294).png
#   inflating: valid/Late_blight/LB_ (297).png
#   inflating: valid/Late_blight/LB_ (299).png
#   inflating: valid/Late_blight/LB_ (3).jpg
#   inflating: valid/Late_blight/LB_ (3).png
#   inflating: valid/Late_blight/LB_ (30).png
#   inflating: valid/Late_blight/LB_ (303).png
#   inflating: valid/Late_blight/LB_ (309).png
#   inflating: valid/Late_blight/LB_ (312).png
#   inflating: valid/Late_blight/LB_ (313).png
#   inflating: valid/Late_blight/LB_ (315).png
#   inflating: valid/Late_blight/LB_ (316).png
#   inflating: valid/Late_blight/LB_ (317).png
#   inflating: valid/Late_blight/LB_ (318).png
#   inflating: valid/Late_blight/LB_ (35).png
#   inflating: valid/Late_blight/LB_ (350).png
#   inflating: valid/Late_blight/LB_ (352).JPG
#   inflating: valid/Late_blight/LB_ (352).png
#   inflating: valid/Late_blight/LB_ (353).png
#   inflating: valid/Late_blight/LB_ (356).png
#   inflating: valid/Late_blight/LB_ (358).JPG
#   inflating: valid/Late_blight/LB_ (358).png
#   inflating: valid/Late_blight/LB_ (36).JPG
#   inflating: valid/Late_blight/LB_ (363).JPG
#   inflating: valid/Late_blight/LB_ (364).JPG
#   inflating: valid/Late_blight/LB_ (365).png
#   inflating: valid/Late_blight/LB_ (366).png
#   inflating: valid/Late_blight/LB_ (373).png
#   inflating: valid/Late_blight/LB_ (375).png
#   inflating: valid/Late_blight/LB_ (376).jpg
#   inflating: valid/Late_blight/LB_ (377).png
#   inflating: valid/Late_blight/LB_ (380).jpg
#   inflating: valid/Late_blight/LB_ (384).jpg
#   inflating: valid/Late_blight/LB_ (385).png
#   inflating: valid/Late_blight/LB_ (388).jpg
#   inflating: valid/Late_blight/LB_ (388).png
#   inflating: valid/Late_blight/LB_ (389).jpg
#   inflating: valid/Late_blight/LB_ (39).JPG
#   inflating: valid/Late_blight/LB_ (390).png
#   inflating: valid/Late_blight/LB_ (395).png
#   inflating: valid/Late_blight/LB_ (396).jpg
#   inflating: valid/Late_blight/LB_ (40).png
#   inflating: valid/Late_blight/LB_ (401).jpg
#   inflating: valid/Late_blight/LB_ (401).png
#   inflating: valid/Late_blight/LB_ (402).jpg
#   inflating: valid/Late_blight/LB_ (409).jpg
#   inflating: valid/Late_blight/LB_ (410).png
#   inflating: valid/Late_blight/LB_ (423).png
#   inflating: valid/Late_blight/LB_ (428).png
#   inflating: valid/Late_blight/LB_ (432).png
#   inflating: valid/Late_blight/LB_ (433).png
#   inflating: valid/Late_blight/LB_ (434).png
#   inflating: valid/Late_blight/LB_ (442).png
#   inflating: valid/Late_blight/LB_ (449).png
#   inflating: valid/Late_blight/LB_ (45).png
#   inflating: valid/Late_blight/LB_ (461).png
#   inflating: valid/Late_blight/LB_ (47).JPG
#   inflating: valid/Late_blight/LB_ (474).png
#   inflating: valid/Late_blight/LB_ (48).JPG
#   inflating: valid/Late_blight/LB_ (5).jpg
#   inflating: valid/Late_blight/LB_ (510).png
#   inflating: valid/Late_blight/LB_ (585).png
#   inflating: valid/Late_blight/LB_ (591).png
#   inflating: valid/Late_blight/LB_ (6).png
#   inflating: valid/Late_blight/LB_ (7).jpg
#   inflating: valid/Late_blight/LB_ (8).jpg
#   inflating: valid/Late_blight/LB_ (98).png
#   inflating: valid/Late_blight/LB_ (99).png
#   inflating: valid/Late_blight/Late_Blight_2_jpg.rf.814e1fc40feb15fd74651e9ff1e752a7.jpg
#   inflating: valid/Late_blight/Lb10.JPG
#   inflating: valid/Late_blight/Lb10_change_180.jpg
#   inflating: valid/Late_blight/Lb11_change_180.jpg
#   inflating: valid/Late_blight/Lb11_mirror.jpg
#   inflating: valid/Late_blight/Lb12_change_90.jpg
#   inflating: valid/Late_blight/Lb12_mirror_vertical.jpg
#   inflating: valid/Late_blight/Lb13_change_180.jpg
#   inflating: valid/Late_blight/Lb13_mirror.jpg
#   inflating: valid/Late_blight/Lb14_mirror.jpg
#   inflating: valid/Late_blight/Lb14_mirror_vertical.jpg
#   inflating: valid/Late_blight/Lb15_mirror.jpg
#   inflating: valid/Late_blight/Lb16_change_180.jpg
#   inflating: valid/Late_blight/Lb18_change_180.jpg
#   inflating: valid/Late_blight/Lb18_hight.jpg
#   inflating: valid/Late_blight/Lb20_change_90.jpg
#   inflating: valid/Late_blight/Lb20_hight.jpg
#   inflating: valid/Late_blight/Lb21_change_270.jpg
#   inflating: valid/Late_blight/Lb22_lower.jpg
#   inflating: valid/Late_blight/Lb22_mirror.jpg
#   inflating: valid/Late_blight/Lb22_mirror_vertical.jpg
#   inflating: valid/Late_blight/Lb23_change_180.jpg
#   inflating: valid/Late_blight/Lb23_change_270.jpg
#   inflating: valid/Late_blight/Lb24.JPG
#   inflating: valid/Late_blight/Lb24_change_270.jpg
#   inflating: valid/Late_blight/Lb25_change_270.jpg
#   inflating: valid/Late_blight/Lb26_change_180.jpg
#   inflating: valid/Late_blight/Lb26_change_270.jpg
#   inflating: valid/Late_blight/Lb27_change_180.jpg
#   inflating: valid/Late_blight/Lb28_change_270.jpg
#   inflating: valid/Late_blight/Lb29_hight.jpg
#   inflating: valid/Late_blight/Lb2_change_180.jpg
#   inflating: valid/Late_blight/Lb2_mirror.jpg
#   inflating: valid/Late_blight/Lb31_mirror_vertical.jpg
#   inflating: valid/Late_blight/Lb32_change_270.jpg
#   inflating: valid/Late_blight/Lb32_change_90.jpg
#   inflating: valid/Late_blight/Lb33_change_270.jpg
#   inflating: valid/Late_blight/Lb33_mirror.jpg
#   inflating: valid/Late_blight/Lb34_change_180.jpg
#   inflating: valid/Late_blight/Lb35_change_180.jpg
#   inflating: valid/Late_blight/Lb35_lower.jpg
#   inflating: valid/Late_blight/Lb35_mirror.jpg
#   inflating: valid/Late_blight/Lb37_change_180.jpg
#   inflating: valid/Late_blight/Lb37_change_90.jpg
#   inflating: valid/Late_blight/Lb37_lower.jpg
#   inflating: valid/Late_blight/Lb37_mirror.jpg
#   inflating: valid/Late_blight/Lb38_lower.jpg
#   inflating: valid/Late_blight/Lb38_mirror.jpg
#   inflating: valid/Late_blight/Lb39_change_180.jpg
#   inflating: valid/Late_blight/Lb39_change_270.jpg
#   inflating: valid/Late_blight/Lb3_change_270.jpg
#   inflating: valid/Late_blight/Lb3_lower.jpg
#   inflating: valid/Late_blight/Lb40.JPG
#   inflating: valid/Late_blight/Lb40_change_90.jpg
#   inflating: valid/Late_blight/Lb40_lower.jpg
#   inflating: valid/Late_blight/Lb40_mirror_vertical.jpg
#   inflating: valid/Late_blight/L
#   inflating: valid/powdery_mildew/pm99_mirror_vertical.jpg
#   inflating: valid/powdery_mildew/pm9_change_270.jpg

# %%
# !mkdir original_data
# !mkdir combine_data
# !mkdir augmented_data

# %%
# Path ke folder dataset asli
train_dir = 'train'
val_dir = 'valid'

# Folder hasil penggabungan
original_data_dir = 'original_data'
os.makedirs(original_data_dir, exist_ok=True)

# Fungsi untuk menggabungkan data dari folder sumber ke folder tujuan
def merge_data(source_dir, destination_dir):
    for class_name in os.listdir(source_dir):
        class_dir = os.path.join(source_dir, class_name)
        if os.path.isdir(class_dir):
            destination_class_dir = os.path.join(destination_dir, class_name)
            os.makedirs(destination_class_dir, exist_ok=True)
            for filename in os.listdir(class_dir):
                src_file = os.path.join(class_dir, filename)

                # Hindari overwrite jika nama file sama
                dst_file = os.path.join(destination_class_dir, filename)
                if os.path.exists(dst_file):
                    name, ext = os.path.splitext(filename)
                    i = 1
                    while os.path.exists(os.path.join(destination_class_dir, f"{name}_{i}{ext}")):
                        i += 1
                    dst_file = os.path.join(destination_class_dir, f"{name}_{i}{ext}")

                shutil.copy(src_file, dst_file)

# Gabungkan data train dan test ke dalam original_data
merge_data(train_dir, original_data_dir)
merge_data(val_dir,original_data_dir)

print("Data telah digabungkan ke dalam folder 'original_data'.")
# Out:
# Data telah digabungkan ke dalam folder 'original_data'.

# %%
# Path ke direktori utama
base_dir = 'original_data'

# Mapping nama folder lama ke nama baru
rename_map = {
    'Spider_mites Two-spotted_spider_mite': 'Tungau_dua_bercak',
    'Tomato_Yellow_Leaf_Curl_Virus': 'Virus_keriting_daun_kuning',
    'powdery_mildew': 'Embun_tepung',
    'Tomato_mosaic_virus': 'Virus_mosaik_tomat',
    'Leaf_Mold': 'Jamur_daun',
    'Septoria_leaf_spot': 'Bercak_daun_Septoria',
    'Early_blight': 'Busuk_daun_awal',
    'Bacterial_spot': 'Bercak_bakteri',
    'healthy': 'Sehat',
    'Late_blight': 'Busuk_daun_lanjut',
    'Target_Spot': 'Bercak_target'
}

# Ganti nama folder
for old_name, new_name in rename_map.items():
    old_path = os.path.join(base_dir, old_name)
    new_path = os.path.join(base_dir, new_name)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"Berhasil mengganti '{old_name}' menjadi '{new_name}'")
    else:
        print(f"Folder '{old_name}' tidak ditemukan")

print("Nama Penyakit dalam folder sudah diganti.")
# Out:
# Berhasil mengganti 'Spider_mites Two-spotted_spider_mite' menjadi 'Tungau_dua_bercak'
# Berhasil mengganti 'Tomato_Yellow_Leaf_Curl_Virus' menjadi 'Virus_keriting_daun_kuning'
# Berhasil mengganti 'powdery_mildew' menjadi 'Embun_tepung'
# Berhasil mengganti 'Tomato_mosaic_virus' menjadi 'Virus_mosaik_tomat'
# Berhasil mengganti 'Leaf_Mold' menjadi 'Jamur_daun'
# Berhasil mengganti 'Septoria_leaf_spot' menjadi 'Bercak_daun_Septoria'
# Berhasil mengganti 'Early_blight' menjadi 'Busuk_daun_awal'
# Berhasil mengganti 'Bacterial_spot' menjadi 'Bercak_bakteri'
# Berhasil mengganti 'healthy' menjadi 'Sehat'
# Berhasil mengganti 'Late_blight' menjadi 'Busuk_daun_lanjut'
# Berhasil mengganti 'Target_Spot' menjadi 'Bercak_target'
# Nama Penyakit dalam folder sudah diganti.

# %%
def visualize_images(base_dir):
    """Menampilkan satu gambar per label dari direktori tertentu."""

    plt.figure(figsize=(15, 15))

    for i, label in enumerate(os.listdir(base_dir)):
        label_dir = os.path.join(base_dir, label)
        if os.path.isdir(label_dir):
            image_files = [f for f in os.listdir(label_dir) if os.path.isfile(os.path.join(label_dir, f))]
            if image_files:
                random_image = random.choice(image_files)
                image_path = os.path.join(label_dir, random_image)
                image = plt.imread(image_path)

                plt.subplot(6, 6, i + 1)
                plt.imshow(image)
                plt.title(label)
                plt.axis('off')

    plt.tight_layout()
    plt.show()

# Contoh visualisasi gambar dari folder training
visualize_images('original_data')

# %%
def plot_class_distribution(dataset_dir):
    """Menampilkan grafik distribusi jumlah gambar per kelas."""
    class_counts = {}

    for class_name in os.listdir(dataset_dir):
        class_dir = os.path.join(dataset_dir, class_name)
        if os.path.isdir(class_dir):
            num_images = len([
                f for f in os.listdir(class_dir)
                if os.path.isfile(os.path.join(class_dir, f))
            ])
            class_counts[class_name] = num_images

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
    plt.title('Distribusi Gambar per Kelas di original_data')
    plt.xlabel('Kelas')
    plt.ylabel('Jumlah Gambar')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Tampilkan grafik
plot_class_distribution('original_data')

# %%
# Path ke dataset asli (tiap kelas di dalam subfolder)
input_base_dir = 'original_data'
output_base_dir = 'augmented_data'

# Mapping kelas dan jumlah gambar tambahan yang diinginkan
augment_target = {
    'Embun_tepung': 2650,
    'Virus_mosaik_tomat': 1150,
    'Busuk_daun_lanjut': 0,
    'Sehat': 0,
    'Jamur_daun': 400,
    'Virus_keriting_daun_kuning': 1300,
    'Bercak_bakteri': 300,
    'Tungau_dua_bercak': 1700,
    'Bercak_target': 1600,
    'Busuk_daun_awal': 800,
    'Bercak_daun_Septoria': 250
}

# Transformasi kombinasi augmentasi
transform = A.Compose([
    A.Rotate(limit=20, p=0.7),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.RandomBrightnessContrast(p=0.5),
    A.ZoomBlur(p=0.2),  # FIXED: tidak lagi pakai zoom_limit
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=0, p=0.5)
])

# Buat output folder jika belum ada
os.makedirs(output_base_dir, exist_ok=True)

# Proses setiap kelas
for class_name, target_aug_count in augment_target.items():
    input_class_dir = os.path.join(input_base_dir, class_name)
    output_class_dir = os.path.join(output_base_dir, class_name)
    os.makedirs(output_class_dir, exist_ok=True)

    image_files = [f for f in os.listdir(input_class_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    num_original = len(image_files)

    if num_original == 0:
        print(f"Skipping {class_name} because no original images were found.")
        continue

    # Hitung berapa augmentasi per gambar asli yang perlu dibuat
    aug_per_image = target_aug_count // num_original + 1

    pbar = tq(total=target_aug_count, desc=f'Augmenting {class_name}')
    total_augmented = 0

    for img_file in image_files:
        if total_augmented >= target_aug_count:
            break

        img_path = os.path.join(input_class_dir, img_file)
        image = cv2.imread(img_path)
        if image is None:
            print(f"Warning: Failed to read {img_path}")
            continue
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        for i in range(aug_per_image):
            if total_augmented >= target_aug_count:
                break
            augmented = transform(image=image)
            aug_image = augmented['image']

            aug_filename = f"{os.path.splitext(img_file)[0]}_aug{total_augmented}.jpg"
            save_path = os.path.join(output_class_dir, aug_filename)
            cv2.imwrite(save_path, cv2.cvtColor(aug_image, cv2.COLOR_RGB2BGR))
            total_augmented += 1
            pbar.update(1)

    pbar.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Augmenting Embun_tepung:   0%|          | 0/2650 [00:00<?, ?it/s]
# Augmenting Virus_mosaik_tomat:   0%|          | 0/1150 [00:00<?, ?it/s]
# Augmenting Busuk_daun_lanjut: 0it [00:00, ?it/s]
# Augmenting Sehat: 0it [00:00, ?it/s]
# Augmenting Jamur_daun:   0%|          | 0/400 [00:00<?, ?it/s]
# Augmenting Virus_keriting_daun_kuning:   0%|          | 0/1300 [00:00<?, ?it/s]
# Augmenting Bercak_bakteri:   0%|          | 0/300 [00:00<?, ?it/s]
# Augmenting Tungau_dua_bercak:   0%|          | 0/1700 [00:00<?, ?it/s]
# Augmenting Bercak_target:   0%|          | 0/1600 [00:00<?, ?it/s]
# Augmenting Busuk_daun_awal:   0%|          | 0/800 [00:00<?, ?it/s]
# Augmenting Bercak_daun_Septoria:   0%|          | 0/250 [00:00<?, ?it/s]

# %%
# Path ke folder dataset asli
original_data = 'original_data'
augmented_data = 'augmented_data'

# Folder hasil penggabungan
original_data_dir = 'combine_data'
os.makedirs(original_data_dir, exist_ok=True)

# Fungsi untuk menggabungkan data dari folder sumber ke folder tujuan
def merge_data(source_dir, destination_dir):
    for class_name in os.listdir(source_dir):
        class_dir = os.path.join(source_dir, class_name)
        if os.path.isdir(class_dir):
            destination_class_dir = os.path.join(destination_dir, class_name)
            os.makedirs(destination_class_dir, exist_ok=True)
            for filename in os.listdir(class_dir):
                src_file = os.path.join(class_dir, filename)

                # Hindari overwrite jika nama file sama
                dst_file = os.path.join(destination_class_dir, filename)
                if os.path.exists(dst_file):
                    name, ext = os.path.splitext(filename)
                    i = 1
                    while os.path.exists(os.path.join(destination_class_dir, f"{name}_{i}{ext}")):
                        i += 1
                    dst_file = os.path.join(destination_class_dir, f"{name}_{i}{ext}")

                shutil.copy(src_file, dst_file)

# Gabungkan data train dan test ke dalam combine_data
merge_data(original_data, original_data_dir)
merge_data(augmented_data,original_data_dir)

print("Data telah digabungkan ke dalam folder 'combine_data'.")
# Out:
# Data telah digabungkan ke dalam folder 'combine_data'.

# %%
def plot_class_distribution(dataset_dir):
    """Menampilkan grafik distribusi jumlah gambar per kelas."""
    class_counts = {}

    for class_name in os.listdir(dataset_dir):
        class_dir = os.path.join(dataset_dir, class_name)
        if os.path.isdir(class_dir):
            num_images = len([
                f for f in os.listdir(class_dir)
                if os.path.isfile(os.path.join(class_dir, f))
            ])
            class_counts[class_name] = num_images

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
    plt.title('Distribusi Gambar per Kelas di original_data')
    plt.xlabel('Kelas')
    plt.ylabel('Jumlah Gambar')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Tampilkan grafik
plot_class_distribution('combine_data')

# %%
# Buat file zip dari folder combine_data
shutil.make_archive('combine_data', 'zip', 'combine_data')
# Out:
# '/content/combine_data.zip'
